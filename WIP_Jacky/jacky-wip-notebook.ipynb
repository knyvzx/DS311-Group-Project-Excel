# %%
import pandas as pd
import sqlite3

conn = sqlite3.Connection("data/data.sqlite")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[55], line 4
#       1 import pandas as pd
#       2 import sqlite3
# ----> 4 conn = sqlite3.Connection("data/data.sqlite")
#
# OperationalError: unable to open database file

# %%
import pandas as pd
import matplotlib.pyplot as plt
"dognition_data_aggregated_by_dogid.xlsx" == '/Jacquelyns-Macbook-Pro/Desktop/DS311-Group-Project-Excel/WIP_Jacky/dognition_data_no_aggregation_with_zip_code_correction.xlsx'
pd.read_excel("dognition_data_no_aggregation_with_zip_code_correction.xlsx")
# Out:
#                 Created_at          Updated_at  \
# 0      2013-05-13 16:17:00 2013-05-13 16:17:00
# 1      2013-05-22 18:54:00 2013-05-22 18:54:00
# 2      2013-05-22 18:55:00 2013-05-22 18:55:00
# 3      2013-05-22 18:56:00 2013-05-22 18:56:00
# 4      2013-05-22 18:58:00 2013-05-22 18:58:00
# ...                    ...                 ...
# 177476 2013-05-14 08:45:00 2013-05-14 08:45:00
# 177477 2013-05-14 08:50:00 2013-05-14 08:50:00
# 177478 2013-05-14 08:54:00 2013-05-14 08:54:00
# 177479 2013-05-19 04:45:00 2013-05-19 04:45:00
# 177480 2013-05-19 05:05:00 2013-05-19 05:05:00
#
#                                      User_ID  \
# 0       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 1       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 2       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 3       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 4       ce134a78-7144-11e5-ba71-058fbc01cf0b
# ...                                      ...
# 177476  ce2777e6-7144-11e5-ba71-058fbc01cf0b
# ...

# %%
df = pd.read_excel("dognition_data_aggregated_by_dogid.xlsx")
df.head()
# Out:
#                                  Dog ID  Total Tests Completed  \
# 0  fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1  fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2  fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3  fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4  fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
#
#    Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0        28.201076        40609.549167           0.004687
# 1         0.413307          595.162281           0.005845
# 2         0.009132           13.150000           0.009132
# 3        56.115179        80805.858333           0.004433
# 4         7.734254        11137.326111           0.000399
#
#    Median ITI (minutes)  Time diff between first and last game (days)  \
# 0              6.750000                                    564.021516
# 1              8.416667                                      7.852836
# ...

# %%
df1 = pd.read_excel("dognition_data_no_aggregation_with_zip_code_correction.xlsx")
df1.head(177481)
# Out:
#                 Created_at          Updated_at  \
# 0      2013-05-13 16:17:00 2013-05-13 16:17:00
# 1      2013-05-22 18:54:00 2013-05-22 18:54:00
# 2      2013-05-22 18:55:00 2013-05-22 18:55:00
# 3      2013-05-22 18:56:00 2013-05-22 18:56:00
# 4      2013-05-22 18:58:00 2013-05-22 18:58:00
# ...                    ...                 ...
# 177476 2013-05-14 08:45:00 2013-05-14 08:45:00
# 177477 2013-05-14 08:50:00 2013-05-14 08:50:00
# 177478 2013-05-14 08:54:00 2013-05-14 08:54:00
# 177479 2013-05-19 04:45:00 2013-05-19 04:45:00
# 177480 2013-05-19 05:05:00 2013-05-19 05:05:00
#
#                                      User_ID  \
# 0       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 1       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 2       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 3       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 4       ce134a78-7144-11e5-ba71-058fbc01cf0b
# ...                                      ...
# 177476  ce2777e6-7144-11e5-ba71-058fbc01cf0b
# ...

# %%
df.describe()
# Out:
#        Total Tests Completed  Mean ITI (days)  Mean ITI (minutes)  \
# count           17986.000000     1.671800e+04        16718.000000
# mean                9.807239     2.300726e+00         3313.045589
# std                 7.799484     1.011768e+01        14569.464530
# min                 1.000000     6.091646e-07            0.000877
# 25%                 4.000000     3.719136e-03            5.355556
# 50%                 7.000000     1.466368e-01          211.157051
# 75%                16.000000     1.226744e+00         1766.511404
# max                45.000000     6.509563e+02       937377.016667
#
#        Median ITI (days)  Median ITI (minutes)  \
# count       16718.000000          16718.000000
# mean            0.275986            397.420037
# std             7.182127          10342.262528
# min             0.000000              0.000000
# 25%             0.002998              4.316667
# 50%             0.003895              5.608333
# ...

# %%
df1.describe()
# Out:
#             Birthday         Weight      Dog_Fixed    DNA_Tested  \
# count  177481.000000  177481.000000  175317.000000  52968.000000
# mean     2009.898265      42.683442       0.876144      0.141633
# std         3.280318      29.171277       0.329418      0.348676
# min      1982.000000       0.000000       0.000000      0.000000
# 25%      2008.000000      20.000000       1.000000      0.000000
# 50%      2011.000000      40.000000       1.000000      0.000000
# 75%      2012.000000      60.000000       1.000000      0.000000
# max      2015.000000     190.000000       1.000000      1.000000
#
#        Sign_in_Count       Max_Dogs  Membership_ID     Subscribed  \
# count  177481.000000  177481.000000   176335.00000  177481.000000
# mean       11.441771       1.373251        7.11325       0.665192
# std        69.452489       1.545094        4.20112       0.471925
# min         0.000000       0.000000        1.00000       0.000000
# ...

# %%
df = pd.read_excel("dognition_data_aggregated_by_dogid.xlsx")
print("\nCol Names:")
print(df.columns)
# Out:
# Col Names:
# Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type'],
#       dtype='object')

# %%
df = pd.read_excel("dognition_data_aggregated_by_dogid.xlsx")
print("\Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type'],
#       dtype='object')

# %%
df1 = pd.read_excel("dognition_data_no_aggregation_with_zip_code_correction.xlsx")
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type'],
#       dtype='object')

# %%
"""
SELECT Membership_ID
COUNT () AS num
FROM Membership_Type ;
"""
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[47], line 6
#       1 """
#       2 SELECT Membership_ID
#       3 COUNT () AS num
#       4 FROM Membership_Type ;
#       5 """
# ----> 6 conn = sqlite3.Connection("Jacquelyns-Macbook-Pro/Desktop/data.sqlite")
#
# OperationalError: unable to open database file

# %%
Features = df1[["Test_name","Subcategory_name",]]
Features.head(10)
# Out:
#              Test_name Subcategory_name
# 0         Yawn Warm-up          Empathy
# 1            Yawn Game          Empathy
# 2  Eye Contact Warm-up          Empathy
# 3     Eye Contact Game          Empathy
# 4        Treat Warm-up    Communication
# 5         Arm Pointing    Communication
# 6        Foot Pointing    Communication
# 7             Watching          Cunning
# 8       Turn Your Back          Cunning
# 9      Cover Your Eyes          Cunning

# %%
Features = df[["Total Tests Completed","Breed","Breed_Type","Breed_Group",]]
Features.head(20)
# Out:
#     Total Tests Completed                                              Breed  \
# 0                      21                                 Labrador Retriever
# 1                      20                                  Shetland Sheepdog
# 2                       2                                   Golden Retriever
# 3                      11                                   Golden Retriever
# 4                      31                                           Shih Tzu
# 5                      20                                     Siberian Husky
# 6                      27                                           Shih Tzu
# 7                      20                                              Mixed
# 8                      20                                 Labrador Retriever
# 9                      20                                Shih Tzu-Poodle Mix
# 10                     14       German Shepherd Dog-Pembroke Welsh Corgi Mix
# ...

# %%
Features = df[["Membership_Type", "Membership_ID", "Free_Start_User"]]
Features.head()
# Out:
#   Membership_Type  Membership_ID Free_Start_User
# 0               2            2.0               0
# 1               1            1.0               0
# 2               1            1.0               0
# 3               1            1.0               0
# 4               2            2.0               0

# %% [markdown]
# # Concatenate the two dataframes into df2
# df2 = pd.concat([df, df1], ignore_index=True)
# # Print column names for the concatenated dataframe
# print("\nColumn Names for df2:")
# print(df2.columns)
#
# df1.info()

# %% [raw]
# df2 = pd.concat([df, df1], ignore_index=True)
# print("\nColumn Names for df2:") print(df2.columns)

# %%
# Replace None with appropriate SQL code
df3 = """
SELECT Membership_ID
FROM Membership_Type
;
"""

df3_result = pd.read_sql(q1, conn)
df3_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       1 # Replace None with appropriate SQL code
#       2 df3 = """
#       3 SELECT Membership_ID
#       4 FROM Membership_Type
#       5 ;
#       6 """
# ----> 8 df3_result = pd.read_sql(q1, conn)
#       9 df3_result
#
# NameError: name 'q1' is not defined

# %%
pd.read_sql ('''
SELECT Membership_ID
, COUNT () AS num
FROM Membership_Type
GROUP BY Membership_Type
ORDER BY COUNT 
''', conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 7
#       1 pd.read_sql ('''
#       2 SELECT Membership_ID
#       3 , COUNT () AS num
#       4 FROM Membership_Type
#       5 GROUP BY Membership_Type
#       6 ORDER BY COUNT
# ----> 7 ''', conn)
#
# NameError: name 'conn' is not defined

# %%
import sqlite3
import pandas as pd

conn = sqlite3.Connection("data/data.sqlite")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 4
#       1 import sqlite3
#       2 import pandas as pd
# ----> 4 conn = sqlite3.Connection("data/data.sqlite")
#
# OperationalError: unable to open database file

# %%
q0 = """
SELECT "Subcategory_name", "Test_name",
FROM "Total Tests Completed"
;
"""
q0_result = pd.read_sql(q0,conn)
q0_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       1 q0 = """
#       2 SELECT "Subcategory_name", "Test_name",
#       3 FROM "Total Tests Completed"
#       4 ;
#       5 """
# ----> 6 q0_result = pd.read_sql(q0,conn)
#       7 q0_result
#
# NameError: name 'conn' is not defined

# %%
Test_name.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Test_name.head(10)
#
# NameError: name 'Test_name' is not defined
