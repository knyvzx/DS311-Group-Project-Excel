# %%
import pandas as pd
df1 = pd.read_excel("dognition_data_aggregated_by_dogid.xlsx")
df1.head()
# Out:
#                                  Dog ID  Total Tests Completed  \
# 0  fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1  fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2  fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3  fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4  fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
#
#    Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0        28.201076        40609.549167           0.004687
# 1         0.413307          595.162281           0.005845
# 2         0.009132           13.150000           0.009132
# 3        56.115179        80805.858333           0.004433
# 4         7.734254        11137.326111           0.000399
#
#    Median ITI (minutes)  Time diff between first and last game (days)  \
# 0              6.750000                                    564.021516
# 1              8.416667                                      7.852836
# ...

# %%
df2 = pd.read_excel('dognition_data_no_aggregation_with_zip_code_correction.xlsx')

df2
# Out:
#                 Created_at          Updated_at  \
# 0      2013-05-13 16:17:00 2013-05-13 16:17:00
# 1      2013-05-22 18:54:00 2013-05-22 18:54:00
# 2      2013-05-22 18:55:00 2013-05-22 18:55:00
# 3      2013-05-22 18:56:00 2013-05-22 18:56:00
# 4      2013-05-22 18:58:00 2013-05-22 18:58:00
# ...                    ...                 ...
# 177476 2013-05-14 08:45:00 2013-05-14 08:45:00
# 177477 2013-05-14 08:50:00 2013-05-14 08:50:00
# 177478 2013-05-14 08:54:00 2013-05-14 08:54:00
# 177479 2013-05-19 04:45:00 2013-05-19 04:45:00
# 177480 2013-05-19 05:05:00 2013-05-19 05:05:00
#
#                                      User_ID  \
# 0       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 1       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 2       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 3       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 4       ce134a78-7144-11e5-ba71-058fbc01cf0b
# ...                                      ...
# 177476  ce2777e6-7144-11e5-ba71-058fbc01cf0b
# ...

# %%
columns_df1 = df1.columns
print("Column names for df1:", columns_df1)
# Out:
# Column names for df1: Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type'],
#       dtype='object')

# %%
columns_df2 = df2.columns
print("Column names for df2:", columns_df2)
# Out:
# Column names for df2: Index(['Created_at', 'Updated_at', 'User_ID', 'Dog_ID', 'Test_name',
#        'Subcategory_name', 'Gender', 'Birthday', 'Breed', 'Breed_Type',
#        'Breed_Group', 'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension',
#        'Sign_in_Count', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City',
#        'State', 'Zip', 'Country', 'Exclude', 'Free_Start_User',
#        'Last_Active_At', 'Membership_Type', 'Rating', 'Rank_by_UserID',
#        'Rank_by_DogID'],
#       dtype='object')

# %%
# Select and display only the 'Dog ID' column from df1
dog_id_column_df1 = df1['Dog ID']
print(dog_id_column_df1.head())
# Select and display only the 'Dog ID' column from df2
dog_id_column_df2 = df2['Dog_ID']
print(dog_id_column_df2.head())
# Out:
# 0    fd27b272-7144-11e5-ba71-058fbc01cf0b
# 1    fd27b5ba-7144-11e5-ba71-058fbc01cf0b
# 2    fd27b6b4-7144-11e5-ba71-058fbc01cf0b
# 3    fd27b79a-7144-11e5-ba71-058fbc01cf0b
# 4    fd27b86c-7144-11e5-ba71-058fbc01cf0b
# Name: Dog ID, dtype: object
# 0    fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 1    fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 2    fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 3    fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# 4    fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# Name: Dog_ID, dtype: object

# %%
# Merge the dataframes on multiple columns
merged_df = pd.merge(df1, df2, left_on=['User ID','Dog ID', 'Gender', 'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude', 'Free_Start_User', 'Last_Active_At', 'Membership_Type'], right_on=['User_ID','Dog_ID', 'Gender', 'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude', 'Free_Start_User', 'Last_Active_At', 'Membership_Type'], how='inner', suffixes=('_df1', '_df2'))

# Display the merged dataframe
merged_df.head()
# Out:
#                                  Dog ID  Total Tests Completed  \
# 0  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 1  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 2  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 3  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 4  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
#
#    Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0        13.520467        19469.473016           0.008171
# 1        13.520467        19469.473016           0.008171
# 2        13.520467        19469.473016           0.008171
# 3        13.520467        19469.473016           0.008171
# 4        13.520467        19469.473016           0.008171
#
#    Median ITI (minutes)  Time diff between first and last game (days)  \
# 0             11.766667                                    283.929815
# 1             11.766667                                    283.929815
# ...

# %%
columns_merged_df = merged_df.columns
print("Column names for merged_df:", columns_merged_df)
# Out:
# Column names for merged_df: Index(['Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'User ID', 'Gender',
#        'Birthday', 'Breed', 'Breed_Type', 'Breed_Group', 'Weight', 'Dog_Fixed',
#        'DNA_Tested', 'Dimension', 'Sign_in_Count', 'Max_Dogs', 'Membership_ID',
#        'Subscribed', 'City', 'State', 'Zip', 'Country', 'Exclude',
#        'Free_Start_User', 'Last_Active_At', 'Membership_Type', 'Created_at',
#        'Updated_at', 'User_ID', 'Dog_ID', 'Test_name', 'Subcategory_name',
#        'Rating', 'Rank_by_UserID', 'Rank_by_DogID'],
#       dtype='object')

# %%
# Sort the merged DataFrame by the 'Dog_Fixed' column
merged_df_sorted = merged_df.sort_values(by='Dog_Fixed')

# Display the sorted DataFrame
merged_df_sorted.head()
# Out:
#                                    Dog ID  Total Tests Completed  \
# 908  fd46ae84-7144-11e5-ba71-058fbc01cf0b                     20
# 518  fd42a366-7144-11e5-ba71-058fbc01cf0b                     42
# 519  fd42a366-7144-11e5-ba71-058fbc01cf0b                     42
# 520  fd42a366-7144-11e5-ba71-058fbc01cf0b                     42
# 521  fd42a366-7144-11e5-ba71-058fbc01cf0b                     42
#
#      Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 908         0.001270            1.828947           0.000868
# 518         9.532181        13726.340650           0.011644
# 519         9.532181        13726.340650           0.011644
# 520         9.532181        13726.340650           0.011644
# 521         9.532181        13726.340650           0.011644
#
#      Median ITI (minutes)  Time diff between first and last game (days)  \
# 908              1.250000                                      0.024132
# ...

# %%
# Filter the merged DataFrame to show only dogs that are fixed
fixed_dogs_df = merged_df[merged_df['Dog_Fixed'] == True]

# Display the filtered DataFrame
fixed_dogs_df.head()
# Out:
#                                  Dog ID  Total Tests Completed  \
# 0  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 1  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 2  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 3  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
# 4  fd3ccf2c-7144-11e5-ba71-058fbc01cf0b                     22
#
#    Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0        13.520467        19469.473016           0.008171
# 1        13.520467        19469.473016           0.008171
# 2        13.520467        19469.473016           0.008171
# 3        13.520467        19469.473016           0.008171
# 4        13.520467        19469.473016           0.008171
#
#    Median ITI (minutes)  Time diff between first and last game (days)  \
# 0             11.766667                                    283.929815
# 1             11.766667                                    283.929815
# ...

# %%
# Filter the merged DataFrame to show only dogs that are not fixed
not_fixed_dogs_df = merged_df[merged_df['Dog_Fixed'] == False]

# Display the filtered DataFrame
not_fixed_dogs_df.head()
# Out:
#                                    Dog ID  Total Tests Completed  \
# 312  fd41f056-7144-11e5-ba71-058fbc01cf0b                     20
# 313  fd41f056-7144-11e5-ba71-058fbc01cf0b                     20
# 314  fd41f056-7144-11e5-ba71-058fbc01cf0b                     20
# 315  fd41f056-7144-11e5-ba71-058fbc01cf0b                     20
# 316  fd41f056-7144-11e5-ba71-058fbc01cf0b                     20
#
#      Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 312         5.052521         7275.630702           0.000278
# 313         5.052521         7275.630702           0.000278
# 314         5.052521         7275.630702           0.000278
# 315         5.052521         7275.630702           0.000278
# 316         5.052521         7275.630702           0.000278
#
#      Median ITI (minutes)  Time diff between first and last game (days)  \
# 312                   0.4                                     95.997905
# ...

# %%
# Create a DataFrame for male dogs
male_dogs_df = merged_df[merged_df['Gender'] == 'male']

# Create a DataFrame for female dogs
female_dogs_df = merged_df[merged_df['Gender'] == 'female']

# Display the DataFrames
print("Male Dogs:")
print(male_dogs_df.head())

print("\nFemale Dogs:")
print(female_dogs_df.head())
# Out:
# Male Dogs:
#                                   Dog ID  Total Tests Completed  \
# 22  fd3d1b44-7144-11e5-ba71-058fbc01cf0b                     20
# 23  fd3d1b44-7144-11e5-ba71-058fbc01cf0b                     20
# 24  fd3d1b44-7144-11e5-ba71-058fbc01cf0b                     20
# 25  fd3d1b44-7144-11e5-ba71-058fbc01cf0b                     20
# 26  fd3d1b44-7144-11e5-ba71-058fbc01cf0b                     20
#
#     Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 22         3.055452         4399.850877            0.00059
# 23         3.055452         4399.850877            0.00059
# 24         3.055452         4399.850877            0.00059
# 25         3.055452         4399.850877            0.00059
# 26         3.055452         4399.850877            0.00059
#
#     Median ITI (minutes)  Time diff between first and last game (days)  \
# 22                  0.85                                     58.053588
# ...

# %%
# Sort male and female dogs in df1 by 'Breed'
sorted_male_dogs_df1 = df1[df1['Gender'] == 'male'].sort_values(by='Breed')
sorted_female_dogs_df1 = df1[df1['Gender'] == 'female'].sort_values(by='Breed')

# Sort male and female dogs in df2 by 'Breed'
sorted_male_dogs_df2 = df2[df2['Gender'] == 'male'].sort_values(by='Breed')
sorted_female_dogs_df2 = df2[df2['Gender'] == 'female'].sort_values(by='Breed')

# Display the sorted DataFrames
print("Male Dogs in df1:")
print(sorted_male_dogs_df1.head())

print("\nFemale Dogs in df1:")
print(sorted_female_dogs_df1.head())

print("\nMale Dogs in df2:")
print(sorted_male_dogs_df2.head())

print("\nFemale Dogs in df2:")
print(sorted_female_dogs_df2.head())
# Out:
# Male Dogs in df1:
#                                      Dog ID  Total Tests Completed  \
# 3035   fd511324-7144-11e5-ba71-058fbc01cf0b                     15
# 14217  fdaf0bc8-7144-11e5-ba71-058fbc01cf0b                      4
# 2494   fd4a6b6e-7144-11e5-ba71-058fbc01cf0b                     20
# 478    fd416050-7144-11e5-ba71-058fbc01cf0b                     20
# 10844  fd7ae6b8-7144-11e5-ba71-058fbc01cf0b                     17
#
#        Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 3035         16.071649        23143.175000           0.004091
# 14217         0.003673            5.288889           0.003218
# 2494          0.004853            6.988596           0.002685
# 478           0.069015           99.381579           0.003021
# 10844         0.145346          209.298958           0.005561
#
#        Median ITI (minutes)  Time diff between first and last game (days)  \
# 3035               5.891667                                    225.003090
# ...

# %%
# Display the summary counts after sorting
print("Summary for Male Dogs in df1:")
print(sorted_male_dogs_df1['Breed'].value_counts())

print("\nSummary for Female Dogs in df1:")
print(sorted_female_dogs_df1['Breed'].value_counts())

print("\nSummary for Male Dogs in df2:")
print(sorted_male_dogs_df2['Breed'].value_counts())

print("\nSummary for Female Dogs in df2:")
print(sorted_female_dogs_df2['Breed'].value_counts())
# Out:
# Summary for Male Dogs in df1:
# Breed
# Mixed                                                2116
# Labrador Retriever                                    616
# Golden Retriever                                      371
# German Shepherd Dog                                   279
# I Don't Know                                          224
#                                                      ...
# Cirneco dell"Etna                                       1
# Clumber Spaniel                                         1
# Cocker Spaniel-Bichon Frise Mix                         1
# Cocker Spaniel-English Cocker Spaniel Mix               1
# Yorkshire Terrier-Soft Coated Wheaten Terrier Mix       1
# Name: count, Length: 902, dtype: int64
#
# Summary for Female Dogs in df1:
# Breed
# Mixed                                      2197
# Labrador Retriever                          568
# Golden Retriever                            340
# German Shepherd Dog                         289
# ...

# %%
# Get the summary counts for male and female dogs in df1
male_counts_df1 = sorted_male_dogs_df1['Breed'].value_counts()
female_counts_df1 = sorted_female_dogs_df1['Breed'].value_counts()

# Get the summary counts for male and female dogs in df2
male_counts_df2 = sorted_male_dogs_df2['Breed'].value_counts()
female_counts_df2 = sorted_female_dogs_df2['Breed'].value_counts()

# Combine the counts for male and female dogs
combined_counts_df1 = pd.DataFrame({'Male': male_counts_df1, 'Female': female_counts_df1})
combined_counts_df2 = pd.DataFrame({'Male': male_counts_df2, 'Female': female_counts_df2})

# Display the combined counts
print("Summary Counts for df1:")
print(combined_counts_df1.head())

print("\nSummary Counts for df2:")
print(combined_counts_df2.head())
# Out:
# Summary Counts for df1:
#                                     Male  Female
# Breed
# Affenpinscher                        5.0     2.0
# Affenpinscher-Brussels Griffon Mix   NaN     1.0
# Afghan Hound                         2.0     3.0
# Afghan Hound-Akita Mix               NaN     1.0
# Afghan Hound-Golden Retriever Mix    NaN     1.0
#
# Summary Counts for df2:
#                                     Male  Female
# Breed
# Affenpinscher                       76.0    22.0
# Affenpinscher-Brussels Griffon Mix   NaN    21.0
# Afghan Hound                        40.0    25.0
# Afghan Hound-Akita Mix               NaN     3.0
# Afghan Hound-Golden Retriever Mix    NaN    20.0

# %%
# Calculate the ratio of males to females for each dog breed in df1
combined_counts_df1['Ratio (Male/Female)'] = combined_counts_df1['Male'] / combined_counts_df1['Female']

# Calculate the ratio of males to females for each dog breed in df2
combined_counts_df2['Ratio (Male/Female)'] = combined_counts_df2['Male'] / combined_counts_df2['Female']

# Display the calculated ratios
print("Ratios for df1:")
print(combined_counts_df1)

print("\nRatios for df2:")
print(combined_counts_df2)
# Out:
# Ratios for df1:
#                                                    Male  Female  \
# Breed
# Affenpinscher                                       5.0     2.0
# Affenpinscher-Brussels Griffon Mix                  NaN     1.0
# Afghan Hound                                        2.0     3.0
# Afghan Hound-Akita Mix                              NaN     1.0
# Afghan Hound-Golden Retriever Mix                   NaN     1.0
# ...                                                 ...     ...
# Yorkshire Terrier-Poodle Mix                       17.0     7.0
# Yorkshire Terrier-Rat Terrier Mix                   NaN     1.0
# Yorkshire Terrier-Shih Tzu Mix                      3.0     3.0
# Yorkshire Terrier-Silky Terrier Mix                 2.0     NaN
# Yorkshire Terrier-Soft Coated Wheaten Terrier Mix   1.0     NaN
#
#                                                    Ratio (Male/Female)
# Breed
# Affenpinscher                                                 2.500000
# ...

# %%
# Display the calculated ratios for df1 without NaN values
print("Ratios for df1:")
print(combined_counts_df1.dropna())

# Display the calculated ratios for df2 without NaN values
print("\nRatios for df2:")
print(combined_counts_df2.dropna())
# Out:
# Ratios for df1:
#                                            Male  Female  Ratio (Male/Female)
# Breed
# Affenpinscher                               5.0     2.0             2.500000
# Afghan Hound                                2.0     3.0             0.666667
# Airedale Terrier                           11.0     9.0             1.222222
# Akita                                       9.0    15.0             0.600000
# Akita-German Shepherd Dog Mix               1.0     1.0             1.000000
# ...                                         ...     ...                  ...
# Yorkshire Terrier-Maltese Mix              12.0     7.0             1.714286
# Yorkshire Terrier-Miniature Schnauzer Mix   5.0     1.0             5.000000
# Yorkshire Terrier-Pomeranian Mix            1.0     1.0             1.000000
# Yorkshire Terrier-Poodle Mix               17.0     7.0             2.428571
# Yorkshire Terrier-Shih Tzu Mix              3.0     3.0             1.000000
#
# ...

# %%
# Sort the DataFrame by the calculated ratios in df1
sorted_ratios_df1 = combined_counts_df1.sort_values(by='Ratio (Male/Female)', ascending=False)

# Sort the DataFrame by the calculated ratios in df2
sorted_ratios_df2 = combined_counts_df2.sort_values(by='Ratio (Male/Female)', ascending=False)

# Display the sorted DataFrames
print("Sorted Ratios for df1:")
print(sorted_ratios_df1.dropna())

print("\nSorted Ratios for df2:")
print(sorted_ratios_df2.dropna())
# Out:
# Sorted Ratios for df1:
#                                                     Male  Female  \
# Breed
# Brussels Griffon                                    15.0     2.0
# Chihuahua-Rat Terrier Mix                            7.0     1.0
# Australian Cattle Dog-Australian Shepherd Mix        7.0     1.0
# American Staffordshire Terrier-American Pit Bull T   7.0     1.0
# Yorkshire Terrier-Miniature Schnauzer Mix            5.0     1.0
# ...                                                  ...     ...
# Irish Water Spaniel                                  1.0     4.0
# Stabyhoun                                            1.0     4.0
# Jack Russell Terrier-Chihuahua Mix                   1.0     4.0
# German Shepherd Dog-Australian Shepherd Mix          1.0     5.0
# Australian Cattle Dog-Labrador Retriever Mix         1.0     9.0
#
#                                                     Ratio (Male/Female)
# Breed
# Brussels Griffon                                               7.500000
# ...
